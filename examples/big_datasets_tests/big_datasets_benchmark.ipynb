# %% [markdown]
# Datasets can be found [here](https://drive.google.com/file/d/1af_Gdt97v-a4KdEhs2NjamWA_kqIODTH/view?usp=sharing).

# %%
from enum import Enum
import pandas as pd
import numpy as np
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
import warnings
from fedot.core.repository.tasks import Task, TaskTypesEnum
from lightgbm import LGBMClassifier, LGBMRegressor
from fedot import Fedot
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score, accuracy_score, f1_score

warnings.filterwarnings("ignore")

class Dataset(Enum):
    AIRLINES = "airlines_train_regression_10M"
    COVERTYPE = "covtype-normalized"
    KDDCUP = "kddcup"
    POLICE_INCIDENTS = "sf-police-incidents"
    SUSY = "SUSY"
    YEAR_PREDICTION_MSD = "year_prediction_msd"


dataset_meta = {
    Dataset.AIRLINES: {
        "task_type": TaskTypesEnum.regression,
        "target_name": "DepDelay",
        "file_name": "airlines_train_regression_10M.csv"
    },
    Dataset.COVERTYPE: {
        "task_type": TaskTypesEnum.classification,
        "target_name": "class",
        "file_name": "covtype-normalized.csv"
    },
    Dataset.KDDCUP: {
        "task_type": TaskTypesEnum.classification,
        "target_name": "label",
        "file_name": "kddcup.csv"
    },
    Dataset.POLICE_INCIDENTS: {
        "task_type": TaskTypesEnum.classification,
        "target_name": "ViolentCrime",
        "file_name": "sf-police-incidents.csv"
    },
    Dataset.SUSY: {
        "task_type": TaskTypesEnum.classification,
        "target_name": 0,
        "file_name": "SUSY.csv"
    },
    Dataset.YEAR_PREDICTION_MSD: {
        "task_type": TaskTypesEnum.regression,
        "target_name": "year",
        "file_name": "year_prediction_msd.csv"
    },
}

# %%
def load_dataset(dataset: Dataset, test_size=0.2):
    df = pd.read_csv(f"datasets/{dataset_meta[dataset]['file_name']}")

    categorical_features = df.select_dtypes(include=["object", "category"]).columns
    for col in categorical_features:
        df[col] = LabelEncoder().fit_transform(df[col].astype(str))

    target_name = dataset_meta[dataset]['target_name']
    if isinstance(target_name, int):
        y = df.iloc[:, target_name]
        x = df.drop(df.columns[target_name], axis=1)
    else:
        y = df[target_name]
        x = df.drop(target_name, axis=1)
    if dataset == Dataset.COVERTYPE:
        y = y.astype(float).astype(int) - 1
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size, random_state=42)
    return x_train, x_test, y_train, y_test

# %%
def print_metrics(task: TaskTypesEnum, model: Fedot, x_test, y_test):
    y_pred = model.predict(x_test)
    if task == TaskTypesEnum.regression:
        print("Test RMSE:", np.sqrt(mean_squared_error(y_test, y_pred)))
        print("Test MAE:", mean_absolute_error(y_test, y_pred))
        print("Test R2:", r2_score(y_test, y_pred))
    else:
        print("Test Accuracy:", accuracy_score(y_test, y_pred))
        print("Test F1 weighted:", f1_score(y_test, y_pred, average='weighted'))
        print("Test F1 macro:", f1_score(y_test, y_pred, average='macro'))

# %%
def train_fedot(dataset: Dataset, timeout=60, test_size=0.2):
    x_train, x_test, y_train, y_test = load_dataset(dataset, test_size=test_size)

    model = Fedot(
        problem=dataset_meta[dataset]['task_type'].value,
        timeout=timeout,
        n_jobs=-1,
        logging_level=20,
        metric='f1' if dataset_meta[dataset]['task_type'] == TaskTypesEnum.classification else 'rmse',
    )
    pipeline = model.fit(features=x_train, target=y_train)
    print_metrics(dataset_meta[dataset]['task_type'], model, x_test, y_test)

# %%
def get_baseline(x_train, x_test, y_train, y_test, task):
    if task.value == "classification":
        model = LGBMClassifier(
            n_estimators=200,
            learning_rate=0.05,
            random_state=42,
            n_jobs=-1,
        )
        model.fit(x_train, y_train)
    elif task.value == "regression":
        model = LGBMRegressor(
            n_estimators=200,
            learning_rate=0.05,
            random_state=42,
            n_jobs=-1
        )
        model.fit(x_train, y_train)

    print_metrics(task, model, x_test, y_test)

# %% [markdown]
# # LGBM baselines

# %%
dataset = Dataset.AIRLINES
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test RMSE: 28.747375173926837
# Test MAE: 13.868159190071447
# Test R2: 0.0439195745612182

# %%
dataset = Dataset.KDDCUP
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test Accuracy: 0.988065576046227
# Test F1 weighted: 0.9852725724250796
# Test F1 macro: 0.16123454275795931

# %%
dataset = Dataset.SUSY
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test Accuracy: 0.801902
# Test F1 weighted: 0.8001104593044638
# Test F1 macro: 0.7976378229414733

# %%
dataset = Dataset.COVERTYPE
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test Accuracy: 0.8585750798172164
# Test F1 weighted: 0.8578788224921586
# Test F1 macro: 0.8465977709563939

# %%
dataset = Dataset.POLICE_INCIDENTS
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test Accuracy: 0.8783354589677317
# Test F1 weighted: 0.8214434485563414
# Test F1 macro: 0.467613734689561

# %%
dataset = Dataset.YEAR_PREDICTION_MSD
x_train, x_test, y_train, y_test = load_dataset(dataset)
get_baseline(x_train, x_test, y_train, y_test, dataset_meta[dataset]['task_type'])
# Out:
# Test RMSE: 9.007852850561541
# Test MAE: 6.2906331003428315
# Test R2: 0.3182254394976818

# %% [markdown]
# # FEDOT random small% baseline

# %%
train_fedot(Dataset.COVERTYPE, timeout=18, test_size=0.7)
# Out:
# 2025-11-07 18:05:19,878 - TableTypesCorrector - Preprocessing was unable to define the categorical columns
# 2025-11-07 18:05:33,597 - AssumptionsHandler - Initial pipeline fitting started
# 2025-11-07 18:06:21,980 - AssumptionsHandler - Initial pipeline was fitted successfully
# 2025-11-07 18:06:21,982 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 438.0 MiB, max: 691.5 MiB
# 2025-11-07 18:06:22,031 - ApiComposer - Initial pipeline was fitted in 51.8 sec.
# 2025-11-07 18:06:22,033 - ApiComposer - Taking into account n_folds=5, estimated fit time for initial assumption is 258.8 sec.
# 2025-11-07 18:06:22,035 - AssumptionsHandler - Preset was changed to fast_train due to fit time estimation for initial model.
# 2025-11-07 18:06:22,055 - ApiComposer - AutoML configured. Parameters tuning: True. Time limit: 15 min. Set of candidate models: ['knn', 'logit', 'normalization', 'pca', 'rf', 'scaling'].
# 2025-11-07 18:06:22,181 - ApiComposer - Timeout is too small for composing and is skipped because fit_time is 258.774655 sec.
# 2025-11-07 18:06:23,671 - DataSourceSplitter - K-folds cross validation is applied.
# 2025-11-07 18:06:23,672 - ApiComposer - Hyperparameters tuning started with 14 min. timeout
# 2025-11-07 18:06:23,674 - SimultaneousTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2025-11-07 18:10:34,337 - SimultaneousTuner - Initial graph: {'depth': 3, 'length': 5, 'nodes': [logit, catboost, scaling, xgboost, lgbm]}
# logit - {}
# catboost - {'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 0.01, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True}
# scaling - {}
# xgboost - {'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30}
# lgbm - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.85, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 20, 'verbose': -1}
# Initial metric: [0.978]
#   0%|          | 0/100000 [00:00<?, ?trial/s, best loss=?]2025-11-07 18:10:34,412 - build_posterior_wrapper took 0.025947 seconds
# 2025-11-07 18:10:34,413 - TPE using 0 trials
# 2025-11-07 18:10:48,185 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.11954107114411607, 'l2_leaf_reg': 6.14838849677531, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 56817970.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 18987, 'colsample_bylevel': 0.47955127941667675, 'iterations': 1801, 'max_leaves': 22};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.019815667172587197, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 26, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.5808841253223189, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.04613136410880282, 'min_data_in_leaf': 35, 'num_leaves': 132, 'reg_alpha': 0.07159260597925962, 'reg_lambda': 5.541236679116401e-07, 'subsample': 0.7396864371648709};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 794, 'colsample_bytree': 0.7834222982771006, 'lambda': 219, 'learning_rate': 0.037356808378920074, 'max_depth': 4, 'min_child_weight': 14, 'scale_pos_weight': 14, 'subsample': 0.5476772537186506};)/n_logit_{'C': 2.5010581518941772}
#   0%|          | 1/100000 [00:13<384:06:47, 13.83s/trial, best loss: inf]2025-11-07 18:10:48,241 - build_posterior_wrapper took 0.025570 seconds
# 2025-11-07 18:10:48,242 - TPE using 1/1 trials with best loss inf
# 2025-11-07 18:11:02,629 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.0621695458798974, 'l2_leaf_reg': 2.4194821553083226, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 16776004.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 22258, 'colsample_bylevel': 0.2665603964702654, 'iterations': 2637, 'max_leaves': 84};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.011080786931867866, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 22, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.7667170259463925, 'force_col_wise': True, 'force_row_wise ': True, 'learning_rate': 0.1425962850146509, 'min_data_in_leaf': 94, 'num_leaves': 80, 'reg_alpha': 0.22664911394478537, 'reg_lambda': 1.2584542523086434e-07, 'subsample': 0.5183847639099848};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 474, 'colsample_bytree': 0.6918211787038611, 'lambda': 961, 'learning_rate': 0.012993826830431593, 'max_depth': 3, 'min_child_weight': 3, 'scale_pos_weight': 2, 'subsample': 0.05788676148961453};)/n_logit_{'C': 2.7328144149811884}
#   0%|          | 2/100000 [00:28<394:11:58, 14.19s/trial, best loss: inf]2025-11-07 18:11:02,686 - build_posterior_wrapper took 0.024864 seconds
# 2025-11-07 18:11:02,687 - TPE using 2/2 trials with best loss inf
# 2025-11-07 18:11:17,077 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.011935213984592434, 'l2_leaf_reg': 1.3447776510297638, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 31.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 24513, 'colsample_bylevel': 0.4125176440607969, 'iterations': 5642, 'max_leaves': 46};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.1530743598838003, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9570423490003295, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.0775684945756673, 'min_data_in_leaf': 81, 'num_leaves': 91, 'reg_alpha': 1.5375758039141834, 'reg_lambda': 0.4581743767090938, 'subsample': 0.6997396178420523};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 997, 'colsample_bytree': 0.08115312177470985, 'lambda': 100, 'learning_rate': 0.1131540063203707, 'max_depth': 6, 'min_child_weight': 5, 'scale_pos_weight': 2, 'subsample': 0.2679055543769466};)/n_logit_{'C': 5.334718998430875}
#   0%|          | 3/100000 [00:42<397:27:05, 14.31s/trial, best loss: inf]2025-11-07 18:11:17,138 - build_posterior_wrapper took 0.028648 seconds
# 2025-11-07 18:11:17,139 - TPE using 3/3 trials with best loss inf
# 2025-11-07 18:11:31,381 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.02659463808460567, 'l2_leaf_reg': 2.566287290837319, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 10, 'min_data_in_leaf': 853590.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 6914, 'colsample_bylevel': 0.6749999920129753, 'iterations': 9887, 'max_leaves': 56};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.6801338129251678, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 44, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.8651631394031396, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.011894892814387933, 'min_data_in_leaf': 74, 'num_leaves': 174, 'reg_alpha': 0.12144366879204747, 'reg_lambda': 2.5168496574093724, 'subsample': 0.7818293933031645, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 844, 'colsample_bytree': 0.655993069612036, 'lambda': 817, 'learning_rate': 0.014943287750497759, 'max_depth': 3, 'min_child_weight': 12, 'scale_pos_weight': 15, 'subsample': 0.1521806946395553};)/n_logit_{'C': 8.65819251702807}
#   0%|          | 4/100000 [00:57<397:22:40, 14.31s/trial, best loss: inf]2025-11-07 18:11:31,437 - build_posterior_wrapper took 0.026159 seconds
# 2025-11-07 18:11:31,439 - TPE using 4/4 trials with best loss inf
# 2025-11-07 18:11:44,728 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.8849189947566019, 'l2_leaf_reg': 8.859262965994573, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 15618.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 6364, 'colsample_bylevel': 0.11443156074835598, 'iterations': 8608, 'max_leaves': 77};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.05852328085437578, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 16, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.48253477253780863, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.01798950979113214, 'min_data_in_leaf': 70, 'num_leaves': 237, 'reg_alpha': 1.7510531797664176e-07, 'reg_lambda': 0.16337860142202137, 'subsample': 0.5852045233731996, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 177, 'colsample_bytree': 0.6201094044901674, 'lambda': 333, 'learning_rate': 0.019799274575686688, 'max_depth': 7, 'min_child_weight': 11, 'scale_pos_weight': 18, 'subsample': 0.10575748941497176};)/n_logit_{'C': 4.302342030075922}
#   0%|          | 5/100000 [01:10<387:46:05, 13.96s/trial, best loss: inf]2025-11-07 18:11:44,785 - build_posterior_wrapper took 0.025921 seconds
# 2025-11-07 18:11:44,786 - TPE using 5/5 trials with best loss inf
# 2025-11-07 18:11:58,127 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.015746453664347387, 'l2_leaf_reg': 3.5122602213238876, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 3706398824.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 9568, 'colsample_bylevel': 0.5840079591397185, 'iterations': 2737, 'max_leaves': 57};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.6556098840587722, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 19, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.7631669834402501, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.061476056539264225, 'min_data_in_leaf': 55, 'num_leaves': 36, 'reg_alpha': 0.29146825306330576, 'reg_lambda': 9.015965410277545, 'subsample': 0.6274082286486902, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 653, 'colsample_bytree': 0.2221810249915886, 'lambda': 326, 'learning_rate': 0.0010588709468762722, 'max_depth': 1, 'min_child_weight': 12, 'scale_pos_weight': 6, 'subsample': 0.08419849013931913};)/n_logit_{'C': 0.5121379910856475}
#   0%|          | 6/100000 [01:23<382:27:59, 13.77s/trial, best loss: inf]2025-11-07 18:11:58,186 - build_posterior_wrapper took 0.027534 seconds
# 2025-11-07 18:11:58,187 - TPE using 6/6 trials with best loss inf
# 2025-11-07 18:12:11,463 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.03840303911613925, 'l2_leaf_reg': 7.243228129408925, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 9690.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 4205, 'colsample_bylevel': 0.19809013950605317, 'iterations': 6667, 'max_leaves': 88};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.09333537511575243, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 38, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.4098025970466183, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.19616894319660977, 'min_data_in_leaf': 56, 'num_leaves': 6, 'reg_alpha': 0.06099033449516416, 'reg_lambda': 0.42673712194804503, 'subsample': 0.41626910088631985, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 729, 'colsample_bytree': 0.7255871002960497, 'lambda': 694, 'learning_rate': 0.4577856893864638, 'max_depth': 5, 'min_child_weight': 11, 'scale_pos_weight': 14, 'subsample': 0.8823388463629779};)/n_logit_{'C': 8.362784455565599}
#   0%|          | 7/100000 [01:37<378:31:24, 13.63s/trial, best loss: inf]2025-11-07 18:12:11,520 - build_posterior_wrapper took 0.026412 seconds
# 2025-11-07 18:12:11,522 - TPE using 7/7 trials with best loss inf
# 2025-11-07 18:12:24,772 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.12599353949814782, 'l2_leaf_reg': 0.9271004169401669, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 60979290161.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 19685, 'colsample_bylevel': 0.6874074281175103, 'iterations': 8040, 'max_leaves': 94};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.1295700918691914, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 50, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.627600271551188, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.06678134386054418, 'min_data_in_leaf': 79, 'num_leaves': 12, 'reg_alpha': 4.424769141042996e-08, 'reg_lambda': 1.7451686574098246e-05, 'subsample': 0.722433624423334, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 852, 'colsample_bytree': 0.46017929520828144, 'lambda': 672, 'learning_rate': 0.001794423214882982, 'max_depth': 5, 'min_child_weight': 7, 'scale_pos_weight': 11, 'subsample': 0.9610145955677487};)/n_logit_{'C': 0.01656723581686463}
#   0%|          | 8/100000 [01:50<375:43:07, 13.53s/trial, best loss: inf]2025-11-07 18:12:24,831 - build_posterior_wrapper took 0.025682 seconds
# 2025-11-07 18:12:24,833 - TPE using 8/8 trials with best loss inf
# 2025-11-07 18:12:38,184 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.06710067349749703, 'l2_leaf_reg': 0.729229823582989, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 9, 'min_data_in_leaf': 13060138.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 17807, 'colsample_bylevel': 0.021715740393889377, 'iterations': 6957, 'max_leaves': 77};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.036431798813013644, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 27, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9674797261787518, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.014226575385419693, 'min_data_in_leaf': 10, 'num_leaves': 7, 'reg_alpha': 0.04035941704018297, 'reg_lambda': 0.031081907632196315, 'subsample': 0.4621253883967245, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 740, 'colsample_bytree': 0.749522712356554, 'lambda': 772, 'learning_rate': 0.05739250592838279, 'max_depth': 4, 'min_child_weight': 15, 'scale_pos_weight': 8, 'subsample': 0.7531916885957552};)/n_logit_{'C': 7.387092634625539}
#   0%|          | 9/100000 [02:03<374:41:52, 13.49s/trial, best loss: inf]2025-11-07 18:12:38,241 - build_posterior_wrapper took 0.026405 seconds
# 2025-11-07 18:12:38,242 - TPE using 9/9 trials with best loss inf
# 2025-11-07 18:12:51,562 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.8356776758908601, 'l2_leaf_reg': 2.665563085747094, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 9, 'min_data_in_leaf': 68681882104.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 53790, 'colsample_bylevel': 0.21636020443334514, 'iterations': 849, 'max_leaves': 31};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.1302758043890903, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 32, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.6140833184442345, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.01694057862229873, 'min_data_in_leaf': 73, 'num_leaves': 86, 'reg_alpha': 0.00030697422418370286, 'reg_lambda': 2.9188636499604154e-06, 'subsample': 0.43733304588360183, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 785, 'colsample_bytree': 0.7087856193720934, 'lambda': 474, 'learning_rate': 0.7813834602862111, 'max_depth': 6, 'min_child_weight': 17, 'scale_pos_weight': 4, 'subsample': 0.64235883647204};)/n_logit_{'C': 8.74408051657987}
#   0%|          | 10/100000 [02:17<373:43:41, 13.46s/trial, best loss: inf]2025-11-07 18:12:51,618 - build_posterior_wrapper took 0.026009 seconds
# 2025-11-07 18:12:51,620 - TPE using 10/10 trials with best loss inf
# 2025-11-07 18:13:04,923 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.16104004666266034, 'l2_leaf_reg': 9.913522718459204, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 9, 'min_data_in_leaf': 37400.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 62263, 'colsample_bylevel': 0.9105624883520318, 'iterations': 9095, 'max_leaves': 20};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.30576230779963204, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 13, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.6398892571130808, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.08626299579073579, 'min_data_in_leaf': 50, 'num_leaves': 100, 'reg_alpha': 0.009241980492100892, 'reg_lambda': 0.0024406949216222626, 'subsample': 0.5018371620847667, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 517, 'colsample_bytree': 0.9086866753975291, 'lambda': 202, 'learning_rate': 0.12791049145347014, 'max_depth': 7, 'min_child_weight': 15, 'scale_pos_weight': 2, 'subsample': 0.18393746236474823};)/n_logit_{'C': 9.714881960430152}
#   0%|          | 11/100000 [02:30<372:54:25, 13.43s/trial, best loss: inf]2025-11-07 18:13:04,979 - build_posterior_wrapper took 0.027197 seconds
# 2025-11-07 18:13:04,980 - TPE using 11/11 trials with best loss inf
# 2025-11-07 18:13:18,234 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.3188829105643577, 'l2_leaf_reg': 4.670025391814036, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 8, 'min_data_in_leaf': 1538882.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 55648, 'colsample_bylevel': 0.6874884235271816, 'iterations': 8073, 'max_leaves': 26};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.7092497994639076, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 7, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9141839424904352, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.015931745407174354, 'min_data_in_leaf': 74, 'num_leaves': 176, 'reg_alpha': 3.856114948606126e-08, 'reg_lambda': 6.356901052106284e-08, 'subsample': 0.43232770871716175, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 418, 'colsample_bytree': 0.34733970501906514, 'lambda': 756, 'learning_rate': 0.08888851229753779, 'max_depth': 2, 'min_child_weight': 8, 'scale_pos_weight': 16, 'subsample': 0.6990302093374663};)/n_logit_{'C': 3.2776529312904197}
#   0%|          | 12/100000 [02:43<371:56:36, 13.39s/trial, best loss: inf]2025-11-07 18:13:18,291 - build_posterior_wrapper took 0.026370 seconds
# 2025-11-07 18:13:18,292 - TPE using 12/12 trials with best loss inf
# 2025-11-07 18:13:31,649 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.10783508764387727, 'l2_leaf_reg': 6.600119863783635, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 10, 'min_data_in_leaf': 564.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 47345, 'colsample_bylevel': 0.9768837720264838, 'iterations': 9886, 'max_leaves': 98};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.8210558621203732, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 50, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9384411769023215, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.029912222989383137, 'min_data_in_leaf': 98, 'num_leaves': 31, 'reg_alpha': 1.4254166859147865e-07, 'reg_lambda': 2.434255199071213, 'subsample': 0.9854232339077755, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 61, 'colsample_bytree': 0.13328446850592998, 'lambda': 903, 'learning_rate': 0.20202071387615717, 'max_depth': 6, 'min_child_weight': 1, 'scale_pos_weight': 3, 'subsample': 0.5835033782098381};)/n_logit_{'C': 6.857198369961247}
#   0%|          | 13/100000 [02:57<372:09:49, 13.40s/trial, best loss: inf]2025-11-07 18:13:31,710 - build_posterior_wrapper took 0.027209 seconds
# 2025-11-07 18:13:31,711 - TPE using 13/13 trials with best loss inf
# 2025-11-07 18:13:44,949 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.1722288958537198, 'l2_leaf_reg': 4.777799526223812, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 144817.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 10888, 'colsample_bylevel': 0.10499466241541816, 'iterations': 8371, 'max_leaves': 80};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.35949037342416107, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 28, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.537748992636602, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.12345690977489596, 'min_data_in_leaf': 38, 'num_leaves': 73, 'reg_alpha': 4.593909722010157, 'reg_lambda': 0.0040079541533935255, 'subsample': 0.6095691384130646, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 366, 'colsample_bytree': 0.12697853093216077, 'lambda': 308, 'learning_rate': 0.012402940211308774, 'max_depth': 3, 'min_child_weight': 15, 'scale_pos_weight': 7, 'subsample': 0.9584829654174692};)/n_logit_{'C': 0.6216087883749928}
#   0%|          | 14/100000 [03:10<371:18:13, 13.37s/trial, best loss: inf]2025-11-07 18:13:45,006 - build_posterior_wrapper took 0.026166 seconds
# 2025-11-07 18:13:45,008 - TPE using 14/14 trials with best loss inf
# 2025-11-07 18:13:58,202 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.028399613219217877, 'l2_leaf_reg': 3.3111209325763182, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 19240774653.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 9914, 'colsample_bylevel': 0.714627318092469, 'iterations': 2411, 'max_leaves': 46};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.4256102280404474, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 10, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.42175104555801, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.012509248834914147, 'min_data_in_leaf': 42, 'num_leaves': 39, 'reg_alpha': 0.371862753556917, 'reg_lambda': 0.0020118688121221356, 'subsample': 0.5974902459105638, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 690, 'colsample_bytree': 0.9110832316075682, 'lambda': 769, 'learning_rate': 0.05970071504324215, 'max_depth': 2, 'min_child_weight': 15, 'scale_pos_weight': 10, 'subsample': 0.28111032790318835};)/n_logit_{'C': 8.97997159909735}
#   0%|          | 15/100000 [03:23<370:19:34, 13.33s/trial, best loss: inf]2025-11-07 18:13:58,259 - build_posterior_wrapper took 0.026009 seconds
# 2025-11-07 18:13:58,260 - TPE using 15/15 trials with best loss inf
# 2025-11-07 18:14:11,535 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.45363634172821177, 'l2_leaf_reg': 2.278123559103024, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 11.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 64614, 'colsample_bylevel': 0.42094988368376485, 'iterations': 1795, 'max_leaves': 76};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.012869556714532411, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 40, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.6995799125072446, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.054840821341235746, 'min_data_in_leaf': 74, 'num_leaves': 31, 'reg_alpha': 0.45911257311964054, 'reg_lambda': 1.3921341064017653e-05, 'subsample': 0.6869482814853871, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 873, 'colsample_bytree': 0.6236282412104265, 'lambda': 934, 'learning_rate': 0.6757063374655464, 'max_depth': 7, 'min_child_weight': 15, 'scale_pos_weight': 5, 'subsample': 0.2388480303103453};)/n_logit_{'C': 5.093748422487748}
#   0%|          | 16/100000 [03:37<370:18:46, 13.33s/trial, best loss: inf]2025-11-07 18:14:11,595 - build_posterior_wrapper took 0.029624 seconds
# 2025-11-07 18:14:11,596 - TPE using 16/16 trials with best loss inf
# 2025-11-07 18:14:24,799 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.06784310587837254, 'l2_leaf_reg': 1.882437772961881, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 436586864.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 21012, 'colsample_bylevel': 0.5867801543338105, 'iterations': 5726, 'max_leaves': 34};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.7586485621219599, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 45, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.7223930256529809, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.06409535609447604, 'min_data_in_leaf': 67, 'num_leaves': 119, 'reg_alpha': 0.0012265835837867896, 'reg_lambda': 1.628118100989e-08, 'subsample': 0.7623804125783913, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 820, 'colsample_bytree': 0.117996174348568, 'lambda': 281, 'learning_rate': 0.24073248143680875, 'max_depth': 6, 'min_child_weight': 5, 'scale_pos_weight': 18, 'subsample': 0.15849944255041698};)/n_logit_{'C': 3.1256022436092694}
#   0%|          | 17/100000 [03:50<369:45:15, 13.31s/trial, best loss: inf]2025-11-07 18:14:24,858 - build_posterior_wrapper took 0.025593 seconds
# 2025-11-07 18:14:24,859 - TPE using 17/17 trials with best loss inf
# 2025-11-07 18:14:38,119 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.3440823157510169, 'l2_leaf_reg': 5.007791009886373, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 9, 'min_data_in_leaf': 149905137.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 10317, 'colsample_bylevel': 0.6345587451670828, 'iterations': 3889, 'max_leaves': 92};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.020874139203716405, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 32, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.7878237463430033, 'force_col_wise': True, 'force_row_wise ': True, 'learning_rate': 0.07123611868798822, 'min_data_in_leaf': 62, 'num_leaves': 25, 'reg_alpha': 1.8293263474363893e-07, 'reg_lambda': 0.0341357179124233, 'subsample': 0.922301260124228, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 887, 'colsample_bytree': 0.7199924266192913, 'lambda': 727, 'learning_rate': 0.0024358545718705937, 'max_depth': 1, 'min_child_weight': 2, 'scale_pos_weight': 6, 'subsample': 0.740678921776957};)/n_logit_{'C': 2.875863516062591}
#   0%|          | 18/100000 [04:03<369:47:16, 13.31s/trial, best loss: inf]2025-11-07 18:14:38,176 - build_posterior_wrapper took 0.025667 seconds
# 2025-11-07 18:14:38,177 - TPE using 18/18 trials with best loss inf
# 2025-11-07 18:14:51,411 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.013258472013149293, 'l2_leaf_reg': 7.424081336364586, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 8, 'min_data_in_leaf': 433.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 49046, 'colsample_bylevel': 0.6751319226137592, 'iterations': 3437, 'max_leaves': 88};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.07791352187374964, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 24, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9205704597810674, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.02915222159165568, 'min_data_in_leaf': 17, 'num_leaves': 256, 'reg_alpha': 1.6678858621407105e-06, 'reg_lambda': 0.09031849102258614, 'subsample': 0.4263437862313816, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 967, 'colsample_bytree': 0.9310284307196816, 'lambda': 650, 'learning_rate': 0.02967580006114605, 'max_depth': 1, 'min_child_weight': 21, 'scale_pos_weight': 12, 'subsample': 0.5824403027417467};)/n_logit_{'C': 9.391914217061117}
#   0%|          | 19/100000 [04:17<369:35:28, 13.31s/trial, best loss: inf]2025-11-07 18:14:51,468 - build_posterior_wrapper took 0.025939 seconds
# 2025-11-07 18:14:51,469 - TPE using 19/19 trials with best loss inf
# 2025-11-07 18:15:04,758 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.04633569289668803, 'l2_leaf_reg': 5.018723855359273, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 5585607583.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 15968, 'colsample_bylevel': 0.2777236308164864, 'iterations': 2211, 'max_leaves': 13};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.3030120515175401, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 48, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.8142994539916849, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.010892318803963604, 'min_data_in_leaf': 94, 'num_leaves': 104, 'reg_alpha': 2.943862148831565e-06, 'reg_lambda': 0.00610798933242037, 'subsample': 0.6372062327889176, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gblinear', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 826, 'colsample_bytree': 0.08172677862994038, 'lambda': 294, 'learning_rate': 0.18998753875725338, 'max_depth': 3, 'min_child_weight': 18, 'scale_pos_weight': 4, 'subsample': 0.44314284844601426};)/n_logit_{'C': 6.7422537691989515}
#   0%|          | 20/100000 [04:30<369:54:53, 13.32s/trial, best loss: inf]2025-11-07 18:15:04,815 - build_posterior_wrapper took 0.025970 seconds
# 2025-11-07 18:15:04,816 - TPE using 20/20 trials with best loss inf
# 2025-11-07 18:15:18,121 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.3267540647216965, 'l2_leaf_reg': 5.948407393020182, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 6, 'min_data_in_leaf': 243452172.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 31231, 'colsample_bylevel': 0.8313053810581305, 'iterations': 9688, 'max_leaves': 4};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.02151872972302997, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 35, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.5582345766237617, 'force_col_wise': True, 'force_row_wise ': True, 'learning_rate': 0.038912360673129774, 'min_data_in_leaf': 27, 'num_leaves': 155, 'reg_alpha': 0.00014619309154564856, 'reg_lambda': 5.397802884826311e-05, 'subsample': 0.8999629387763074, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 596, 'colsample_bytree': 0.81256794784617, 'lambda': 23, 'learning_rate': 0.004821893001719041, 'max_depth': 4, 'min_child_weight': 18, 'scale_pos_weight': 9, 'subsample': 0.4213287611341552};)/n_logit_{'C': 1.7878847219926857}
#   0%|          | 21/100000 [04:43<370:16:45, 13.33s/trial, best loss: inf]2025-11-07 18:15:18,179 - build_posterior_wrapper took 0.026086 seconds
# 2025-11-07 18:15:18,180 - TPE using 21/21 trials with best loss inf
# 2025-11-07 18:15:31,525 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.01836301162418124, 'l2_leaf_reg': 8.135242995563985, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 8, 'min_data_in_leaf': 694.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 42148, 'colsample_bylevel': 0.48607673418604874, 'iterations': 1063, 'max_leaves': 6};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.05312227301445312, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 24, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.4853434984269909, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.026273319287445297, 'min_data_in_leaf': 7, 'num_leaves': 242, 'reg_alpha': 1.4535182943390853e-05, 'reg_lambda': 8.857711975632094e-07, 'subsample': 0.8399783795890862, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 992, 'colsample_bytree': 0.965638999029938, 'lambda': 572, 'learning_rate': 0.034463663006302915, 'max_depth': 5, 'min_child_weight': 20, 'scale_pos_weight': 12, 'subsample': 0.49762917689751085};)/n_logit_{'C': 1.4451832810501866}
#   0%|          | 22/100000 [04:57<370:51:40, 13.35s/trial, best loss: inf]2025-11-07 18:15:31,585 - build_posterior_wrapper took 0.029858 seconds
# 2025-11-07 18:15:31,587 - TPE using 22/22 trials with best loss inf
# ...
#   0%|          | 40/100000 [09:02<372:51:03, 13.43s/trial, best loss: inf]2025-11-07 18:19:36,653 - build_posterior_wrapper took 0.026062 seconds
# 2025-11-07 18:19:36,654 - TPE using 40/40 trials with best loss inf
# 2025-11-07 18:19:50,017 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.04307247901941325, 'l2_leaf_reg': 3.144824448089899, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 1422951443.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 13905, 'colsample_bylevel': 0.2236589853707565, 'iterations': 1804, 'max_leaves': 9};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.12300831769963674, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 15, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.8636606998041995, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.044846409693148695, 'min_data_in_leaf': 52, 'num_leaves': 135, 'reg_alpha': 7.360937671116432e-07, 'reg_lambda': 0.00013000183025233236, 'subsample': 0.6976252271117844, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 375, 'colsample_bytree': 0.01156919806313561, 'lambda': 496, 'learning_rate': 0.5509764286039844, 'max_depth': 1, 'min_child_weight': 14, 'scale_pos_weight': 15, 'subsample': 0.10491134317640516};)/n_logit_{'C': 7.678203491828255}
#   0%|          | 41/100000 [09:15<372:46:00, 13.43s/trial, best loss: inf]2025-11-07 18:19:50,072 - build_posterior_wrapper took 0.026356 seconds
# 2025-11-07 18:19:50,073 - TPE using 41/41 trials with best loss inf
# 2025-11-07 18:20:03,390 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.12151565171462593, 'l2_leaf_reg': 6.96072045420375, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 18868466298.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 5941, 'colsample_bylevel': 0.019846718913953232, 'iterations': 8681, 'max_leaves': 16};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.979826669594014, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 17, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.9939800847498256, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.08131144610591864, 'min_data_in_leaf': 25, 'num_leaves': 118, 'reg_alpha': 0.02036357470670989, 'reg_lambda': 0.010233329083283664, 'subsample': 0.8236868718238581, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 785, 'colsample_bytree': 0.28026547353480197, 'lambda': 441, 'learning_rate': 0.10151942388538747, 'max_depth': 2, 'min_child_weight': 18, 'scale_pos_weight': 13, 'subsample': 0.40667632132115894};)/n_logit_{'C': 6.375120572350985}
#   0%|          | 42/100000 [09:29<372:20:32, 13.41s/trial, best loss: inf]2025-11-07 18:20:03,446 - build_posterior_wrapper took 0.026252 seconds
# 2025-11-07 18:20:03,448 - TPE using 42/42 trials with best loss inf
# 2025-11-07 18:20:17,289 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.41100641735544585, 'l2_leaf_reg': 4.28662210363563, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 33319.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 20106, 'colsample_bylevel': 0.9335334033271789, 'iterations': 8829, 'max_leaves': 36};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.026823660271701334, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 38, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.5656729104239168, 'force_col_wise': True, 'force_row_wise ': True, 'learning_rate': 0.0335852630457933, 'min_data_in_leaf': 32, 'num_leaves': 186, 'reg_alpha': 0.0029982744018586965, 'reg_lambda': 0.0006695260400459144, 'subsample': 0.9990953606277932, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 145, 'colsample_bytree': 0.8542395580447555, 'lambda': 4, 'learning_rate': 0.0026183700755111577, 'max_depth': 3, 'min_child_weight': 6, 'scale_pos_weight': 8, 'subsample': 0.05268942831903556};)/n_logit_{'C': 4.670847303341201}
#   0%|          | 43/100000 [09:42<376:25:16, 13.56s/trial, best loss: inf]2025-11-07 18:20:17,347 - build_posterior_wrapper took 0.026919 seconds
# 2025-11-07 18:20:17,348 - TPE using 43/43 trials with best loss inf
# 2025-11-07 18:20:31,059 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.9616013578089925, 'l2_leaf_reg': 6.420632916291102, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 4, 'min_data_in_leaf': 62834494.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 13113, 'colsample_bylevel': 0.8831716896689383, 'iterations': 3097, 'max_leaves': 63};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.01650990678512401, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 38, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.6485072935460726, 'force_col_wise': False, 'force_row_wise ': True, 'learning_rate': 0.11094488658166345, 'min_data_in_leaf': 64, 'num_leaves': 188, 'reg_alpha': 0.11084370226316442, 'reg_lambda': 0.5534773242488975, 'subsample': 0.9537996985883673, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 267, 'colsample_bytree': 0.7344897428634946, 'lambda': 1000, 'learning_rate': 0.00814870011118503, 'max_depth': 4, 'min_child_weight': 11, 'scale_pos_weight': 7, 'subsample': 0.3450512235973752};)/n_logit_{'C': 1.9067722867152774}
#   0%|          | 44/100000 [09:56<378:10:16, 13.62s/trial, best loss: inf]2025-11-07 18:20:31,114 - build_posterior_wrapper took 0.026551 seconds
# 2025-11-07 18:20:31,116 - TPE using 44/44 trials with best loss inf
# 2025-11-07 18:20:44,549 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.031243759001362687, 'l2_leaf_reg': 9.266445492865476, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 10, 'min_data_in_leaf': 4685.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 51054, 'colsample_bylevel': 0.6251662250876198, 'iterations': 1986, 'max_leaves': 21};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.03912853831264702, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 22, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.4453565159167928, 'force_col_wise': True, 'force_row_wise ': False, 'learning_rate': 0.013826701850796728, 'min_data_in_leaf': 9, 'num_leaves': 229, 'reg_alpha': 0.000514833676049957, 'reg_lambda': 5.664416202082242e-07, 'subsample': 0.7838024859233937, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 922, 'colsample_bytree': 0.9968844038563053, 'lambda': 355, 'learning_rate': 0.04221376655120067, 'max_depth': 7, 'min_child_weight': 12, 'scale_pos_weight': 15, 'subsample': 0.5448040780992277};)/n_logit_{'C': 2.6569322838644087}
#   0%|          | 45/100000 [10:10<376:29:34, 13.56s/trial, best loss: inf]
# 2025-11-07 18:20:44,586 - SimultaneousTuner - Hyperparameters optimization finished
# 2025-11-07 18:20:57,227 - PipelineObjectiveEvaluate - Unsuccessful pipeline fit during fitness evaluation. Skipping the pipeline. Exception <only one of the parameters border_count, max_bin should be initialized.> on ((/n_scaling;)/n_catboost_{'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.11954107114411607, 'l2_leaf_reg': 6.14838849677531, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 7, 'min_data_in_leaf': 56817970.0, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True, 'border_count': 18987, 'colsample_bylevel': 0.47955127941667675, 'iterations': 1801, 'max_leaves': 22};;(/n_scaling;)/n_lgbm_{'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.019815667172587197, 'extra_trees': True, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 26, 'n_jobs': 20, 'verbose': -1, 'colsample_bytree': 0.5808841253223189, 'force_col_wise': False, 'force_row_wise ': False, 'learning_rate': 0.04613136410880282, 'min_data_in_leaf': 35, 'num_leaves': 132, 'reg_alpha': 0.07159260597925962, 'reg_lambda': 5.541236679116401e-07, 'subsample': 0.7396864371648709, 'class_weight': 'balanced'};;(/n_scaling;)/n_xgboost_{'n_jobs': 20, 'verbosity': 0, 'booster': 'dart', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'alpha': 794, 'colsample_bytree': 0.7834222982771006, 'lambda': 219, 'learning_rate': 0.037356808378920074, 'max_depth': 4, 'min_child_weight': 14, 'scale_pos_weight': 14, 'subsample': 0.5476772537186506};)/n_logit_{'C': 2.5010581518941772}
# 2025-11-07 18:20:57,257 - SimultaneousTuner - Return init graph due to the fact that obtained metric is None. Initial metric is 0.979
# 2025-11-07 18:20:57,259 - SimultaneousTuner - Final graph: {'depth': 3, 'length': 5, 'nodes': [logit, catboost, scaling, xgboost, lgbm]}
# logit - {}
# catboost - {'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 0.01, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True}
# scaling - {}
# xgboost - {'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30}
# lgbm - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.85, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 20, 'verbose': -1}
# 2025-11-07 18:20:57,260 - SimultaneousTuner - Final metric: 0.978
# 2025-11-07 18:20:57,263 - ApiComposer - Hyperparameters tuning finished
# 2025-11-07 18:20:57,412 - ApiComposer - Model generation finished
# 2025-11-07 18:22:03,266 - FEDOT logger - Final pipeline was fitted
# 2025-11-07 18:22:03,268 - FEDOT logger - Final pipeline: {'depth': 3, 'length': 5, 'nodes': [logit, catboost, scaling, xgboost, lgbm]}
# logit - {}
# catboost - {'n_jobs': 20, 'num_trees': 3000, 'learning_rate': 0.03, 'l2_leaf_reg': 0.01, 'bootstrap_type': 'Bernoulli', 'grow_policy': 'SymmetricTree', 'max_depth': 5, 'min_data_in_leaf': 1, 'one_hot_max_size': 10, 'fold_permutation_block': 1, 'boosting_type': 'Plain', 'od_type': 'Iter', 'od_wait': 100, 'max_bin': 32, 'feature_border_type': 'GreedyLogSum', 'nan_mode': 'Min', 'verbose': False, 'allow_writing_files': False, 'use_eval_set': True, 'use_best_model': True, 'enable_categorical': True}
# scaling - {}
# xgboost - {'n_jobs': 20, 'verbosity': 0, 'booster': 'gbtree', 'tree_method': 'auto', 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30}
# lgbm - {'boosting_type': 'gbdt', 'max_depth': -1, 'bagging_fraction': 0.85, 'extra_trees': False, 'enable_categorical': True, 'use_eval_set': True, 'early_stopping_rounds': 30, 'n_jobs': 20, 'verbose': -1}
# 2025-11-07 18:22:03,270 - MemoryAnalytics - Memory consumption for finish in main session: current 505.3 MiB, max: 765.2 MiB
# Test Accuracy: 0.8690341251361539
# Test F1 weighted: 0.8686982333869296
# Test F1 macro: 0.8451750442016689

# %%
train_fedot(Dataset.AIRLINES, timeout=12, test_size=0.97)
# Out:
# 2025-11-07 18:23:48,462 - TableTypesCorrector - Preprocessing defines the following columns as categorical: [0 2]
# 2025-11-07 18:23:50,892 - AssumptionsHandler - Initial pipeline fitting started
# 2025-11-07 18:26:02,322 - fedot.core.caching.base_cache - Nodes can not be saved
# Traceback (most recent call last):
#   File "/home/artem/PycharmProjects/FEDOT_fork/fedot/core/caching/operations_cache.py", line 36, in save_nodes
#     self._db.add_operations(mapped)
#   File "/home/artem/PycharmProjects/FEDOT_fork/fedot/core/caching/operations_cache_db.py", line 97, in add_operations
#     cur.executemany(f'INSERT OR IGNORE INTO {self._main_table} VALUES (?, ?);', pickled)
# sqlite3.InterfaceError: Error binding parameter 1 - probably unsupported type.
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/home/artem/PycharmProjects/FEDOT_fork/.venv/lib/python3.10/site-packages/golem/core/log.py", line 196, in log_or_raise
#     raise exc from recent_exc
# ValueError: Nodes can not be saved
# 2025-11-07 18:26:04,959 - AssumptionsHandler - Initial pipeline was fitted successfully
# 2025-11-07 18:26:04,960 - AssumptionsHandler - Memory consumption for fitting of the initial pipeline in main session: current 2980.3 MiB, max: 3678.4 MiB
# 2025-11-07 18:26:04,961 - ApiComposer - Initial pipeline was fitted in 134.1 sec.
# 2025-11-07 18:26:04,961 - ApiComposer - Taking into account n_folds=5, estimated fit time for initial assumption is 670.7 sec.
# 2025-11-07 18:26:04,962 - AssumptionsHandler - Preset was changed to fast_train due to fit time estimation for initial model.
# 2025-11-07 18:26:04,969 - ApiComposer - AutoML configured. Parameters tuning: True. Time limit: 10 min. Set of candidate models: ['adareg', 'knnreg', 'lasso', 'linear', 'normalization', 'pca', 'ransac_lin_reg', 'rfr', 'ridge', 'scaling'].
# 2025-11-07 18:26:05,054 - ApiComposer - Timeout is too small for composing and is skipped because fit_time is 670.66684 sec.
# 2025-11-07 18:26:05,057 - DataSourceSplitter - Stratificated splitting of data is disabled.
# 2025-11-07 18:26:05,059 - DataSourceSplitter - K-folds cross validation is applied.
# 2025-11-07 18:26:05,060 - ApiComposer - Hyperparameters tuning started with 8 min. timeout
# 2025-11-07 18:26:05,062 - SimultaneousTuner - Hyperparameters optimization start: estimation of metric for initial graph
# 2025-11-07 18:27:38,895 - SimultaneousTuner - Initial graph: {'depth': 2, 'length': 2, 'nodes': [rfr, scaling]}
# rfr - {'n_jobs': 20}
# scaling - {}
# Initial metric: [29.775]
#   0%|          | 0/100000 [00:00<?, ?trial/s, best loss=?]2025-11-07 18:27:38,907 - build_posterior_wrapper took 0.003510 seconds
# 2025-11-07 18:27:38,908 - TPE using 0 trials
#   0%|          | 1/100000 [01:28<2465:59:29, 88.78s/trial, best loss: 29.85668607810237]2025-11-07 18:29:07,686 - build_posterior_wrapper took 0.003738 seconds
# 2025-11-07 18:29:07,687 - TPE using 1/1 trials with best loss 29.856686
#   0%|          | 2/100000 [03:03<2557:22:40, 92.07s/trial, best loss: 29.85668607810237]2025-11-07 18:30:42,057 - build_posterior_wrapper took 0.003953 seconds
# 2025-11-07 18:30:42,058 - TPE using 2/2 trials with best loss 29.856686
#   0%|          | 3/100000 [04:11<2254:45:44, 81.17s/trial, best loss: 29.089480613421586]2025-11-07 18:31:50,267 - build_posterior_wrapper took 0.003670 seconds
# 2025-11-07 18:31:50,268 - TPE using 3/3 trials with best loss 29.089481
#   0%|          | 4/100000 [05:27<2201:56:26, 79.27s/trial, best loss: 29.089480613421586]2025-11-07 18:33:06,626 - build_posterior_wrapper took 0.003731 seconds
# 2025-11-07 18:33:06,627 - TPE using 4/4 trials with best loss 29.089481
#   0%|          | 5/100000 [06:39<2219:39:01, 79.91s/trial, best loss: 29.089480613421586]
# 2025-11-07 18:34:18,463 - SimultaneousTuner - Hyperparameters optimization finished
# 2025-11-07 18:35:24,730 - SimultaneousTuner - Return tuned graph due to the fact that obtained metric 29.089 equal or better than initial (+ 0.05% deviation) 29.760
# 2025-11-07 18:35:24,732 - SimultaneousTuner - Final graph: {'depth': 2, 'length': 2, 'nodes': [rfr, scaling]}
# rfr - {'n_jobs': 20, 'bootstrap': False, 'max_features': 0.6167113598665775, 'min_samples_leaf': 12, 'min_samples_split': 7}
# scaling - {}
# 2025-11-07 18:35:24,733 - SimultaneousTuner - Final metric: 29.089
# 2025-11-07 18:35:24,735 - ApiComposer - Hyperparameters tuning finished
# 2025-11-07 18:35:24,896 - ApiComposer - Model generation finished
# 2025-11-07 18:35:42,217 - FEDOT logger - Final pipeline was fitted
# 2025-11-07 18:35:42,221 - FEDOT logger - Final pipeline: {'depth': 2, 'length': 2, 'nodes': [rfr, scaling]}
# rfr - {'n_jobs': 20, 'bootstrap': False, 'max_features': 0.6167113598665775, 'min_samples_leaf': 12, 'min_samples_split': 7}
# scaling - {}
# 2025-11-07 18:35:42,223 - MemoryAnalytics - Memory consumption for finish in main session: current 1300.4 MiB, max: 3678.4 MiB
# Test RMSE: 29.105188740577574
# Test MAE: 14.083285276748253
# Test R2: 0.02333022367367199
